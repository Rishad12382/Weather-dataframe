# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc5f0394-a8cf-4214-af65-6b6bbf73c55e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc5f0394-a8cf-4214-af65-6b6bbf73c55e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Weather.csv to Weather.csv

# %%
import io

# %%
df = pd.read_csv(io.BytesIO(uploaded['Weather.csv']))
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %% [markdown]
# **Data explore**

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C  ...  Visibility_km    Press_kPa
# count  8784.000000       8784.000000  ...    8784.000000  8784.000000
# mean      8.798144          2.555294  ...      27.664447   101.051623
# std      11.687883         10.883072  ...      12.622688     0.844005
# min     -23.300000        -28.500000  ...       0.200000    97.520000
# 25%       0.100000         -5.900000  ...      24.100000   100.560000
# 50%       9.300000          3.300000  ...      25.000000   101.070000
# 75%      18.800000         11.800000  ...      25.000000   101.590000
# max      33.000000         24.400000  ...      48.300000   103.650000
#
# [8 rows x 6 columns]

# %%
df.Weather.value_counts

# %%
#Question answer
#1.find all the unique ' wind speed' value in the data
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
#2.find the number of times when the 'weather is  Clear'
df.Weather.value_counts()

# %%
df[df.Weather =='Clear']
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 67      1/3/2012 19:00   -16.9  ...     101.74    Clear
# 114     1/5/2012 18:00    -7.1  ...     100.71    Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80    Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83    Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83    Clear
# ...                ...     ...  ...        ...      ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %%
#3.find the number of times when the 'wind speed was exactly 19km/h'
df.head(2)

# %%
df[df['Wind Speed_km/h']==19]

# %%
#4.find out all the null values in the data
df.isnull().sum()

# %%
#5.rename the coumn name'Weather' to 'Weather Condition'
df.rename(columns={'Weather' : 'Weather Condition'}, inplace=True)

# %%
df.head(2)

# %%
#6.what is the mean 'Visibility'
df.Visibility_km.mean()

# %%
#7.what is the Standard deviation of 'pressure' in this data?
df['Press_kPa']

# %%
df.Press_kPa.std()

# %%
#8.What is the variance of 'relative humidity' in this data?
df['Rel Hum_%'].var()

# %%
#9.find all instances when 'Snow' was recorded.
df['Weather Condition'].value_counts()

# %%
df[df['Weather Condition']=='Snow']

# %%
df[df['Weather Condition'].str.contains('Snow')]

# %%
#10.find all instaces when ' wind speed is above 24' and visibilty is  25.
df.head(2)

# %%
df[(df['Wind Speed_km/h']>24) & (df['Visibility_km']==25)]

# %%
#11.what is the Mean value of each column against each 'Weather Condition'?
df.groupby('Weather Condition').mean()

# %%
#12.what is the minimum&maximun value of each column against each'Weather Condition'
df.groupby('Weather Condition').min()

# %%
df.groupby('Weather Condition').max()

# %%
#13.show all the records where weather condition is fog.
df[df['Weather Condition'] =='Fog']

# %%
#14.find all instances when 'weather is mostly cloudy' or 'visibility is above 40'
df.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
df[(df['Weather Condition']== 'Mostly Cloudy') | (df['Visibility_km']>40)].head(10)

# %%
#15.Weather is clear and r humidity is grater than 50 or visibility  is above 40 
#Use and and or operator  together
df[(df['Weather Condition'] == 'Clear')&(df['Rel Hum_%']>50) | (df['Visibility_km']>40)].tail(10)

# %% [markdown]
# **Data Visualization**

# %%
df.plot()

# %%
sns.barplot(df['Weather Condition'], df['Rel Hum_%'])

# %%
sns.displot(df['Wind Speed_km/h'])

# %%
sns.jointplot(df['Wind Speed_km/h'], df['Rel Hum_%'])

# %%
sns.jointplot(df['Wind Speed_km/h'], df['Rel Hum_%'], kind='hex')

# %%
sns.pairplot(df[['Wind Speed_km/h','Rel Hum_%','Dew Point Temp_C']])

# %%
sns.boxplot(df['Wind Speed_km/h'], df['Rel Hum_%'], hue=df['Weather Condition'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['Wind Speed_km/h'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pointplot(df['Wind Speed_km/h'], df['Rel Hum_%'], hue=df['Weather Condition'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.swarmplot(df['Rel Hum_%'], df['Temp_C'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 44.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
